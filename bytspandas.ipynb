# %%
import numpy as np
import pandas as pd
a=np.array([1,2,3,4,5,6])
print(type(a))
print(a)
# Out:
# <class 'numpy.ndarray'>
# [1 2 3 4 5 6]

# %%
s=pd.Series([1,2,3,4,5])
print(type(s))
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s=pd.Series([1,2,3,4,5])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
ss=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(ss)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
print(ss.drop('a',inplace=True))
# Out:
# None

# %%
print(s.drop(2))
print(s.iloc[2])
# Out:
# 0    1
# 1    2
# 3    4
# 4    5
# dtype: int64
# 3

# %%
data=[['Alex',10,'23-05-2000'],['Bob',None,None],['clarke',None,'23-08-2005'],['karthik',None,'05-05-2004']]
print(pd.DataFrame(data))
print(data[0:2])
# Out:
#          0     1           2
# 0     Alex  10.0  23-05-2000
# 1      Bob   NaN        None
# 2   clarke   NaN  23-08-2005
# 3  karthik   NaN  05-05-2004
# [['Alex', 10, '23-05-2000'], ['Bob', None, None]]

# %%
columnName=pd.DataFrame(data,columns=['First Name','Age','Dob'])
print(columnName)
# Out:
#   First Name   Age         Dob
# 0       Alex  10.0  23-05-2000
# 1        Bob   NaN        None
# 2     clarke   NaN  23-08-2005
# 3    karthik   NaN  05-05-2004

# %%
print(columnName['First Name'][0])
print(columnName.loc[0,'First Name'])
print(columnName[0:1])
# Out:
# Alex
# Alex
#   First Name   Age         Dob
# 0       Alex  10.0  23-05-2000

# %%
a=pd.Series([100,22,340,450,55])
print(a)
print(a.plot())
#print(a.hist(bins=2))
# Out:
# 0    100
# 1     22
# 2    340
# 3    450
# 4     55
# dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
print(a.hist(bins=2))
print(type(a))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# <class 'pandas.core.series.Series'>

# %%
#CONVERT A PANDAS SERIES TO NUMPY
k=a.to_numpy()
print(k)


print(type(a))
# Out:
# [100  22 340 450  55]
# <class 'pandas.core.series.Series'>

# %%
#first value in dataframe
print(columnName.head(1))
print(columnName.tail(-1))
# Out:
#   First Name   Age         Dob
# 0       Alex  10.0  23-05-2000
#   First Name  Age         Dob
# 1        Bob  NaN        None
# 2     clarke  NaN  23-08-2005
# 3    karthik  NaN  05-05-2004

# %%
#python null values -> None,'',' ','-','?','Nil',np.nan(Not a number)
print(columnName.isnull().sum())
# Out:
# First Name    0
# Age           3
# Dob           1
# dtype: int64

# %%
data=[['Alex',10,'23-05-2000'],['Bob',None,None],['clarke',None,'23-08-2005'],['karthik',None,None],['abc',78,'24-09-2004'],['xyz',56,None],['def','?',None]]
k=pd.DataFrame(data)
#print(k)

print(k.isnull().sum())
# Out:
# 0    0
# 1    3
# 2    4
# dtype: int64

# %%
print(k.dropna())
#k.drop?
# Out:
#       0   1           2
# 0  Alex  10  23-05-2000
# 4   abc  78  24-09-2004

# %%
karth=[['Alex',10,'23-05-2000'],['Bob',None,None],['clarke',None,'23-08-2005'],['karthik',None,'05-05-2004']]
lin=pd.DataFrame(karth)
#(lin.drop([1],axis=1,inplace=True))#inplcae is like a commit or will update the new table
lin.drop([0,1,3])#drop that index
# Out:
#         0   1           2
# 2  clarke NaN  23-08-2005

# %%
a=pd.Series([10,12,13,44,56])
k=a.to_numpy()
print(k)
# Out:
# [10 12 13 44 56]

# %%
print(k[k>40])
print(k>40)
# Out:
# [44 56]
# [False False False  True  True]

# %%
a=pd.Series([5,6,7,8,9,145,287,2654,33,44,55,66,98,99,81])
typ=a.to_numpy()
print(typ[typ%2!=0])
print(typ<6)
# Out:
# [  5   7   9 145 287  33  55  99  81]
# [ True False False False False False False False False False False False
#  False False False]

# %%
data=[['Alex',10,'23-05-2000'],['Bob',None,None],['clarke',None,'23-08-2005']]
lok=pd.DataFrame(data)
print(lok.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       1 non-null      float64
#  2   2       2 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 200.0+ bytes
# None

# %%
print(lok[0].str.contains('e'))
# Out:
# 0     True
# 1    False
# 2     True
# Name: 0, dtype: bool

# %%
print(lok[0].str.contains('B'))
# Out:
# 0    False
# 1     True
# 2    False
# Name: 0, dtype: bool

# %%
#pandas has following attributes:
print(lok.shape)
print(lok.axes)
print(lok.size)
print(lok.ndim)
print(lok.dtypes)
print(lok.index)
print(lok.columns)
print(lok.values)

# %%
print(pd.concat([lok,lok]))
print(lok.describe())
# Out:
#         0     1           2
# 0    Alex  10.0  23-05-2000
# 1     Bob   NaN        None
# 2  clarke   NaN  23-08-2005
# 0    Alex  10.0  23-05-2000
# 1     Bob   NaN        None
# 2  clarke   NaN  23-08-2005
#           1
# count   1.0
# mean   10.0
# std     NaN
# min    10.0
# 25%    10.0
# 50%    10.0
# 75%    10.0
# max    10.0

# %%
print(lok.loc[0,0])
print(lok.loc[1,0])
)
# Out:
# Alex
# 20-04-2002
#             0           1           2
# 0        Alex        10.0  23-05-2000
# 1  20-04-2002  20-04-2002        None
# 2  20-04-2002  24-05-2005  23-08-2005

# %%
import pandas as pd
data1=[['Alex',10,'23-05-2000'],['Bob',None,None],['clarke',None,'23-08-2005'],['karthik',None,None],['abc',78,'24-09-2004'],['xyz',56,None],['def','?',None]]
pk=pd.DataFrame(data1)

# %%
readHtml=pd.read_html("https://en.wikipedia.org/wiki/HTML")
print(readHtml)
# Out:
# [                                                    0  \
# 0   The official logo of the latest version, HTML5[1]
# 1                                  Filename extension
# 2                                 Internet media type
# 3                                           Type code
# 4                       Uniform Type Identifier (UTI)
# 5                                        Developed by
# 6                                     Initial release
# 7                                      Latest release
# 8                                      Type of format
# 9                                       Container for
# 10                                       Contained by
# 11                                      Extended from
# 12                                        Extended to
# 13                                       Open format?
# 14                                            Website
#
#                                                     1
# ...

# %%
#to read a csv file
#test = pd.read_csv("/MLEX2.csv")
#to read tsv files:
testThe=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
print(testThe)
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
test=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/titanic_test.csv")
print(test)
# Out:
#     PassengerId,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 0    892,3,"Kelly, Mr. James",male,34.5,0,0,330911,...
# 1    893,3,"Wilkes, Mrs. James (Ellen Needs)",femal...
# 2    894,2,"Myles, Mr. Thomas Francis",male,62,0,0,...
# 3    895,3,"Wirz, Mr. Albert",male,27,0,0,315154,8....
# 4    896,3,"Hirvonen, Mrs. Alexander (Helga E Lindq...
# ..                                                 ...
# 413  1305,3,"Spector, Mr. Woolf",male,,0,0,A.5. 323...
# 414  1306,1,"Oliva y Ocana, Dona. Fermina",female,3...
# 415  1307,3,"Saether, Mr. Simon Sivertsen",male,38....
# 416  1308,3,"Ware, Mr. Frederick",male,,0,0,359309,...
# 417  1309,3,"Peter, Master. Michael J",male,,1,1,26...
#
# [418 rows x 1 columns]

# %%
print(testThe.isnull().sum())
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
testThe.item_price=testThe.item_price.str.replace('$','')
testThe
# Out:
# <ipython-input-32-8b89aaad9446>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   testThe.item_price=testThe.item_price.str.replace('$','')
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# ...

# %%
testThe.item_price=testThe.item_price.astype(float)
testThe
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
testThe.item_price=testThe.item_price*1
testThe
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
print(testThe[testThe.item_price<1.4])
# Out:
#       order_id  quantity          item_name choice_description  item_price
# 28          14         1        Canned Soda       [Dr. Pepper]        1.09
# 34          17         1      Bottled Water                NaN        1.09
# 53          24         1        Canned Soda           [Sprite]        1.09
# 87          38         1      Bottled Water                NaN        1.09
# 107         47         1        Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...                ...                ...         ...
# 4585      1823         1  Canned Soft Drink        [Diet Coke]        1.25
# 4597      1826         1  Canned Soft Drink           [Nestea]        1.25
# 4601      1827         1  Canned Soft Drink        [Diet Coke]        1.25
# 4606      1828         1  Canned Soft Drink             [Coke]        1.25
# 4609      1829         1  Canned Soft Drink           [Sprite]        1.25
#
# [370 rows x 5 columns]

# %%
testThe.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
testThe.drink=testThe[testThe.item_price<1.1]
testThe.drink.item_name.nunique()
# Out:
# 2

# %%
testThe.drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
testThe
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
testThe[testThe.item_name=='Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
testThe[testThe.item_name=='Steak Burrito']
# Out:
#       order_id  quantity      item_name  \
# 7            4         1  Steak Burrito
# 9            5         1  Steak Burrito
# 31          16         1  Steak Burrito
# 43          20         1  Steak Burrito
# 46          21         1  Steak Burrito
# ...        ...       ...            ...
# 4546      1807         1  Steak Burrito
# 4607      1829         1  Steak Burrito
# 4610      1830         1  Steak Burrito
# 4617      1833         1  Steak Burrito
# 4618      1833         1  Steak Burrito
#
#                                      choice_description  item_price
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        9.25
# 31    [[Roasted Chili Corn Salsa (Medium), Fresh Tom...        8.99
# 43    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...       11.75
# 46    [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...        8.99
# ...                                                 ...         ...
# ...

# %%
testThe[testThe.item_name=='Steak Burrito'].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# ...

# %%
testThe[testThe.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
testThe.dropna(inplace=True)
testThe[testThe.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
testThe[(testThe.item_name=='Chicken Bowl')& (testThe.item_price<10)].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
df=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[(df.star_rating>6)& (df.content_rating=='R')].sort_values(['duration'])



#testThe[(testThe.item_name=='Chicken Bowl')& (testThe.item_price<10)].sort_values(['item_price'])
# Out:
#      star_rating                              title content_rating      genre  \
# 742          7.6                          Following              R    Mystery
# 864          7.5                              [Rec]              R     Horror
# 533          7.8                       Run Lola Run              R     Action
# 283          8.1                      Before Sunset              R      Drama
# 541          7.8  South Park: Bigger Longer & Uncut              R  Animation
# ..           ...                                ...            ...        ...
# 671          7.7                         Grindhouse              R     Action
# 424          7.9                    The Right Stuff              R  Adventure
# 8            8.9                   Schindler's List              R  Biography
# 2            9.1             The Godfather: Part II              R      Crime
# 78           8.4        Once Upon a Time in America              R      Crime
#
# ...

# %%
df[(df.star_rating>6)& (df.content_rating=='R') & (df.title=="Following")].sort_values(['duration'])
# Out:
#      star_rating      title content_rating    genre  duration  \
# 742          7.6  Following              R  Mystery        69
#
#                                            actors_list
# 742  [u'Jeremy Theobald', u'Alex Haw', u'Lucy Russe...

# %%
df[df.actors_list.str.contains("Leonardo DiCaprio")].sort_values(['duration','star_rating'])
# Out:
#      star_rating                        title content_rating      genre  \
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 244          8.1               Shutter Island              R    Mystery
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 309          8.0                Blood Diamond              R  Adventure
# 11           8.8                    Inception          PG-13     Action
# 49           8.5                 The Departed              R      Crime
# 59           8.5             Django Unchained              R    Western
# 828          7.5            Gangs of New York              R      Crime
# 888          7.5                  The Aviator          PG-13  Biography
# 143          8.2      The Wolf of Wall Street              R  Biography
# 620          7.7                      Titanic          PG-13      Drama
#
#      duration                                        actors_list
# ...

# %%
df[df.actors_list.str.contains("Tom Hanks")].sort_values(['star_rating'])
# Out:
#      star_rating                title content_rating      genre  duration  \
# 842          7.5          Cloud Atlas              R      Drama       172
# 754          7.6            Apollo 13             PG  Adventure       140
# 817          7.6     Saving Mr. Banks          PG-13  Biography       125
# 587          7.7    Road to Perdition              R      Crime       117
# 629          7.7            Cast Away          PG-13  Adventure       143
# 644          7.7         Philadelphia          PG-13      Drama       125
# 414          7.9          Toy Story 2              G  Animation        92
# 447          7.9     Captain Phillips          PG-13  Biography       134
# 340          8.0  Catch Me If You Can          PG-13  Biography       141
# 117          8.3            Toy Story              G  Animation        81
# 81           8.4          Toy Story 3              G  Animation       103
# 40           8.5       The Green Mile              R      Crime       189
# ...

# %%
df[df.actors_list.str.contains("Leonardo DiCaprio")].sort_values(['duration','star_rating'],ascending=(True,False))
#i have a star rating but i dont consider it ,based on the duration only i sorted,so for using this i use ascending function
# Out:
#      star_rating                        title content_rating      genre  \
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 244          8.1               Shutter Island              R    Mystery
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 309          8.0                Blood Diamond              R  Adventure
# 11           8.8                    Inception          PG-13     Action
# 49           8.5                 The Departed              R      Crime
# 59           8.5             Django Unchained              R    Western
# 828          7.5            Gangs of New York              R      Crime
# 888          7.5                  The Aviator          PG-13  Biography
# 143          8.2      The Wolf of Wall Street              R  Biography
# 620          7.7                      Titanic          PG-13      Drama
#
#      duration                                        actors_list
# ...

# %%
ufo=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
drinks=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks.beer_servings.min()
# Out:
# 0

# %%
drinks.beer_servings.max()
# Out:
# 376

# %%
drinks[drinks.continent=="Asia"].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
drinks[drinks.continent=="Asia"].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
drinks.groupby("continent").beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby("continent").beer_servings.agg(['mean','min','max'])
# Out:
#                      mean  min  max
# continent
# Africa          61.471698    0  376
# Asia            37.045455    0  247
# Europe         193.777778    0  361
# North America  145.434783    1  285
# Oceania         89.687500    0  306
# South America  175.083333   93  333
