# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x=np.array([1,2,3,4,5])
y=np.array([2.1,3.8,6.5,9.2,11.3])
degree=2
x_poly=np.column_stack([x**i for i in range (degree+1)])
x_poly
# Out:
# array([[ 1,  1,  1],
#        [ 1,  2,  4],
#        [ 1,  3,  9],
#        [ 1,  4, 16],
#        [ 1,  5, 25]])

# %%
weight=np.zeros(degree+1)
weight
# Out:
# array([0., 0., 0.])

# %%
learning_rate=0.001
number_Of_iteration=10
for i in range(number_Of_iteration):
  predictions=np.dot(x_poly,weight)
  error=predictions-y
  gradient=np.dot(x_poly.T,error)/len(x)col
  weight-=learning_rate*gradient
  print(f'weights for iteration{_}:{weight}')
# Out:
# weights for iteration[0.00658 0.0245  0.1011 ]:[0.00658 0.0245  0.1011 ]
# weights for iteration[0.01196782 0.04416126 0.18122974]:[0.01196782 0.04416126 0.18122974]
# weights for iteration[0.01640984 0.05998424 0.24472605]:[0.01640984 0.05998424 0.24472605]
# weights for iteration[0.02010149 0.07276252 0.29502889]:[0.02010149 0.07276252 0.29502889]
# weights for iteration[0.02319779 0.08312552 0.33486681]:[0.02319779 0.08312552 0.33486681]
# weights for iteration[0.02582168 0.09157254 0.36640406]:[0.02582168 0.09157254 0.36640406]
# weights for iteration[0.02807069 0.0984996  0.39135734]:[0.02807069 0.0984996  0.39135734]
# weights for iteration[0.03002219 0.10422081 0.41108832]:[0.03002219 0.10422081 0.41108832]
# weights for iteration[0.03173754 0.10898534 0.42667704]:[0.03173754 0.10898534 0.42667704]
# weights for iteration[0.03326539 0.11299082 0.43898023]:[0.03326539 0.11299082 0.43898023]

# %%
def predict(x,weight):
  x_poly=np.array([x**i for i in range (degree+1)])
  return np.dot(x_poly,weight)

# %%
plt.scatter(x,y,label="Data Points")
x_range=np.linspace(min(x),max(x),100)
y_pred=[predict(x,weight) for x in x_range]
plt.plot(x_range,y_pred,color='r',label="Polynomial regression")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
